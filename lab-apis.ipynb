# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "<introduce your client id>"
CLIENT_SECRET = "<introduce your client secret>"

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))
sp

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=10)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=0&limit=10',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4VIvfOurcf0vuLRxLkGnIG'},
#        'href': 'https://api.spotify.com/v1/artists/4VIvfOurcf0vuLRxLkGnIG',
#        'id': '4VIvfOurcf0vuLRxLkGnIG',
#        'name': 'Bradley Cooper',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VIvfOurcf0vuLRxLkGnIG'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
# ...

# %%
results = sp.artist_top_tracks('1HY2Jd0NmPuamShAr6KMms', country="US")
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#       'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#       'id': '1HY2Jd0NmPuamShAr6KMms',
#       'name': 'Lady Gaga',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1jpUMnKpRlng1OJN7LJauV'},
#     'href': 'https://api.spotify.com/v1/albums/1jpUMnKpRlng1OJN7LJauV',
#     'id': '1jpUMnKpRlng1OJN7LJauV',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273631810af03785dbad83f5c81',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02631810af03785dbad83f5c81',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851631810af03785dbad83f5c81',
#       'width': 64}],
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"][0].keys() # Let's check the values
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results["tracks"][0]["name"]
# Out:
# 'Poker Face'

# %%
results["tracks"]["href"] # Query we have searched

# %%
results["tracks"]["items"] #items (actual tracks)

# %%
results["tracks"]["limit"]#Limit we have chosen

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?query=Lady+Gaga&type=track&offset=50&limit=50'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 906

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 results["tracks"]["items"][0]
#
# TypeError: list indices must be integers or slices, not str

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Track artists
# ----> 2 results["tracks"]["items"][0]["artists"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Track artists names
# ----> 2 for artist in results["tracks"]["items"][0]["artists"]:
#       3     print(artist["name"])
#
# TypeError: list indices must be integers or slices, not str

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Track ID
# ----> 2 results["tracks"]["items"][0]["id"]
#
# TypeError: list indices must be integers or slices, not str

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Houdini'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 92

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:2rbDhOo9Fh61Bbu23T2qCk'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %%
#Checking for artist adele
results = sp.artist_top_tracks('4dpARuHxo51G3z768sgnrY', country="US")
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#       'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#       'id': '4dpARuHxo51G3z768sgnrY',
#       'name': 'Adele',
#       'type': 'artist',
#       'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0Lg1uZvI312TPqxNWShFXL'},
#     'href': 'https://api.spotify.com/v1/albums/0Lg1uZvI312TPqxNWShFXL',
#     'id': '0Lg1uZvI312TPqxNWShFXL',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732118bf9b198b05a95ded6300',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022118bf9b198b05a95ded6300',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512118bf9b198b05a95ded6300',
#       'width': 64}],
# ...

# %%
"""artists = ["Adele", "Christina Aguilera", "Eminem"]
artist_id= []
for artist in artists:
    results = sp.search(q=artist, limit=10)
    artist_id.append(results["tracks"]["items"][0]["artists"][0]["id"] )
artist_id"""
# Out:
# 'artists = ["Adele", "Christina Aguilera", "Eminem"]\nartist_id= []\nfor artist in artists:\n    results = sp.search(q=artist, limit=10)\n    artist_id.append(results["tracks"]["items"][0]["artists"][0]["id"] )\nartist_id'

# %%
# Listing the names of the Artists and getting their id

artists = ["Adele", "Christina Aguilera", "Eminem"]

artist_id=[sp.search(q=artist, limit=10)["tracks"]["items"][0]["artists"][0]["id"] for artist in artists]
artist_id
# Out:
# ['4dpARuHxo51G3z768sgnrY', '1l7ZsJRRS8wlW3WfJfPfNS', '7dGJo4pcD2V6oG8kP0tJRR']

# %%
# Your answer here
def get_top_tracks(artist_id):
    for a_id in artist_id:
        top_tracks_list=[sp.artist_top_tracks(a_id, country="US")["tracks"][i]["name"]  for i in range(0,5)]
    return 

get_top_tracks(artist_id)

top_tracks_list
# Out:
#   Cell In[81], line 6
#     return top_tracks_list
#     ^
# SyntaxError: 'return' outside function

# %%
"""def get_top_tracks(a_id):
    top_tracks_list=[]
    results = sp.artist_top_tracks(a_id, country="US")
    for i in range(0,5):
        top_tracks_list.append(results["tracks"][i]["name"])
    return 

for a_id in artist_id:
    get_top_tracks(a_id)

top_tracks_list"""
# Out:
# ['Set Fire to the Rain',
#  'Easy On Me',
#  'Someone Like You',
#  'Rolling in the Deep',
#  'Skyfall',
#  'Moves Like Jagger - Studio Recording From The Voice Performance',
#  'Feel This Moment (feat. Christina Aguilera)',
#  'Genie In a Bottle',
#  'Say Something',
#  'Lady Marmalade - Single Edit',
#  'Houdini',
#  'Without Me',
#  'Tobey (feat. Big Sean and BabyTron)',
#  'Mockingbird',
#  'The Real Slim Shady']

# %%
#3. **Discover Related Artists**:

def find_related_artists(enter_artist_name):
   results = sp.search(q= enter_artist_name, limit=1)
   artist_id = results["tracks"]["items"][0]["artists"][0]["id"] 
   related_artist_list=[sp.artist_related_artists(artist_id)["artists"][i]["name"] for i in range(0,5)]
   return related_artist_list

# %%
enter_artist_name= input("Please enter an artist name: ")
find_related_artists(enter_artist_name)
# Out:
# ['Rita Ora', 'Bebe Rexha', 'Clean Bandit', 'Zara Larsson', 'Tove Lo']

# %%
 """results = sp.artist_related_artists(artist_id)
   for i in range(0,5):
      related_artist_list.append(results["artists"][i]["name"])
   return related_artist_list"""

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
results.keys()
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"][0].keys()
# Out:
# dict_keys(['album', 'artists', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
results["tracks"][0]["name"]
# Out:
# 'Set Fire to the Rain'

# %%
results["tracks"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 results["tracks"][0]["name"]
#
# KeyError: 0

# %%
results = sp.search(q='Christina Aguilera', limit=5)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Christina+Aguilera&type=track&offset=0&limit=5',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1l7ZsJRRS8wlW3WfJfPfNS'},
#        'href': 'https://api.spotify.com/v1/artists/1l7ZsJRRS8wlW3WfJfPfNS',
#        'id': '1l7ZsJRRS8wlW3WfJfPfNS',
#        'name': 'Christina Aguilera',
#        'type': 'artist',
#        'uri': 'spotify:artist:1l7ZsJRRS8wlW3WfJfPfNS'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
# ...

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %%
sp.featured_playlists() # We get a playlist id of a playlist we like
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Os grandes hits reunidos numa playlist única! Foto: Karol G',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#     'id': '37i9dQZF1DX0rV7skaITBo',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c7f584ea66fca61ebe1542d3',
#       'width': None}],
#     'name': 'Hot Hits Portugal',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
playlist_id = "37i9dQZF1DXd9zR7tdziuQ"
playlist = sp.playlist(playlist_id)

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# Hits acústicos
# Relájate con tus canciones favoritas en versión acústica / Descontrai com versões acústicas das tuas músicas preferidas.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
tracks = sp.playlist_tracks(playlist_id)
for track in tracks['items']:
    print(track['track']['name'])  # Print each track's name
# Out:
# Take Me Home, Country Roads
# La Vie En Rose
# You Are My Sunshine
# Sunday Morning - Acoustic
# Too Good At Goodbyes - Acoustic
# True Colours
# I'm Not the Only One - Live from Spotify, London
# Cold Heart - Acoustic
# Collide - Acoustic Version
# September Song - Guitar Acoustic
# Baby One More Time - Recorded at Spotify Studios New York City
# If You Ever Wanna Be In Love - James Bay Spotify Session 2015
# Rockabye - Acoustic Version
# When You Love Someone - Acoustic
# Blinding Lights
# Perfect - Acoustic
# Little Talks
# Ain't Nobody (Loves Me Better) - Acoustic
# What About Us - Acoustic
# Something Just Like This - Acoustic
# Shape of You - Acoustic
# Let It Go - James Bay Spotify Session 2015
# Linger
# Heaven Is a Place on Earth
# 1973 - Acoustic
# Billie Jean
# Crazy in Love
# Naked - Acoustic Version
# Firestone - Live Acoustic Version
# Fix You - Live
# Can't Help Falling in Love
# Wild Love - Acoustic
# Slow Dancing in a Burning Room - Acoustic
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['Lana Del Rey', 'Daniela Andrade', 'Jasmine Thompson', 'Maroon 5', 'Sam Smith', 'Tom Odell', 'Dua Lipa', 'Elton John', 'Howie Day', 'JP Cooper', 'Ed Sheeran', 'James Bay', 'The Mayries', 'James TW', 'Ouvindo', 'Julia Sheer', 'Jon D', 'Thomas Daniel', 'Missy & Blonde', 'Julia Ross', 'Freedom Fry', 'James Blunt', 'The Civil Wars', 'James Arthur', 'Kygo', 'Conrad Sewell', 'Kacey Musgraves', 'John Mayer', 'Jessie J', 'The Wind and The Wave', 'Megan Davies', 'Keelan Donovan', 'Lotte Kestner', 'Halloran & Kate', 'Calum Scott', 'John Legend', 'Sixpence None The Richer', 'Joy Williams', 'The Lumineers', 'Obadiah Parker', 'Lily Allen', 'Frente!', 'Gavin James', 'Molly Parden', 'Hollow Hum', 'Sara Farell', 'Daniel Powter', 'William Fitzsimmons', 'Joanna Wang', 'Niall Horan', 'Sia', 'Becca Adams', 'Lykke Li', 'Sarah Jarosz', 'Alex Cornell', 'Rachel Brown', 'Sunset & Highland', 'Rita Ora', 'Kyle Nachtigal', "Israel Kamakawiwo'ole", 'Clementine Duo', 'Arlo Parks', 'Jaclyn Davies', 'Catey Shaw', 
# ...

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
# Your answer here

sp.featured_playlists()
result = sp.featured_playlists()
result.keys()
# Out:
# dict_keys(['message', 'playlists'])

# %%
result
# Out:
# {'message': 'Popular Playlists',
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': 'Os grandes hits reunidos numa playlist única! Foto: Karol G',
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#     'id': '37i9dQZF1DX0rV7skaITBo',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000002c7f584ea66fca61ebe1542d3',
#       'width': None}],
#     'name': 'Hot Hits Portugal',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
#     'primary_color': '#FFFFFF',
#     'public': True,
# ...

# %%
result['playlists']
# Out:
# {'href': 'https://api.spotify.com/v1/browse/featured-playlists?offset=0&limit=20',
#  'items': [{'collaborative': False,
#    'description': 'Os grandes hits reunidos numa playlist única! Foto: Karol G',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#    'id': '37i9dQZF1DX0rV7skaITBo',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67706f00000002c7f584ea66fca61ebe1542d3',
#      'width': None}],
#    'name': 'Hot Hits Portugal',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': '#FFFFFF',
#    'public': True,
#    'snapshot_id': 'ZqeOSwAAAACGD5yJalEKwpNn/Vwiep7Y',
# ...

# %%
result['playlists']['items'][0]
# Out:
# {'collaborative': False,
#  'description': 'Os grandes hits reunidos numa playlist única! Foto: Karol G',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX0rV7skaITBo'},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo',
#  'id': '37i9dQZF1DX0rV7skaITBo',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f00000002c7f584ea66fca61ebe1542d3',
#    'width': None}],
#  'name': 'Hot Hits Portugal',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#FFFFFF',
#  'public': True,
#  'snapshot_id': 'ZqeOSwAAAACGD5yJalEKwpNn/Vwiep7Y',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX0rV7skaITBo/tracks',
#   'total': 50},
#  'type': 'playlist',
# ...

# %%
"""1. **Featured Exploration**: 
   - Fetch the list of Spotify's current featured playlists. 
   - Extract and display the names and IDs of the top 5 featured playlists."""

for i in range(0,5):
    top_playlist_name = result['playlists']['items'][i]['name']
    print(top_playlist_name)
    top_playlist_id = result['playlists']['items'][i]['id']
    print(top_playlist_id)
# Out:
# Hot Hits Portugal
# 37i9dQZF1DX0rV7skaITBo
# Funk Hits
# 37i9dQZF1DWTkIwO2HDifB
# Top Brasil
# 37i9dQZF1DX0FOF1IUWK1W
# Today’s Top Hits
# 37i9dQZF1DXcBWIGoYBM5M
# Viral Hits Portugal 2024
# 37i9dQZF1DX1nm5hRRaekn

# %%
"""2. **Deep Dive**:
   - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
   - Fetch and display its name, description, and total track count."""

result['playlists']['items'][1]
# Out:
# {'collaborative': False,
#  'description': 'É Qu Eu Te Sarrei e os funks mais 🔑 do Brasil. Foto: Mc Arizinho, DJ THG, Tavin',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTkIwO2HDifB'},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTkIwO2HDifB',
#  'id': '37i9dQZF1DWTkIwO2HDifB',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f0000000265c3358d3fff33549f55f9d7',
#    'width': None}],
#  'name': 'Funk Hits',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': '#eb1e32',
#  'public': True,
#  'snapshot_id': 'ZqMR5AAAAADSldTTOgBK0b4r8X4BWuPl',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTkIwO2HDifB/tracks',
#   'total': 51},
#  'type': 'playlist',
# ...

# %%
print("Name of the track: ",result['playlists']['items'][1]["name"])
print("Description: ",result['playlists']['items'][1]['description'])
print("Number of total tracks: ",result['playlists']['items'][1]['tracks']['total'])
# Out:
# Name of the track:  Funk Hits
# Description:  É Qu Eu Te Sarrei e os funks mais 🔑 do Brasil. Foto: Mc Arizinho, DJ THG, Tavin
# Number of total tracks:  51

# %%
playlist_id = result['playlists']['items'][1]["id"]
playlist_id
# Out:
# '37i9dQZF1DWTkIwO2HDifB'

# %%
tracks = sp.playlist_tracks(playlist_id)
tracks
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTkIwO2HDifB/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-07-26T03:03:00Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/ca29bb1453e57b4a06153f07ba2dc796f72c20c1?cid=4109b2d9f5014671863bb2df1d1fbdd3',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
for track in tracks['items'][:10]:    
    print(track['track']['name'])
      # Print each track's name
# Out:
# É Que Eu Te Sarrei
# THE BOX MEDLEY FUNK 2
# Samba de Malandro
# QUERO VER SE VOCÊ TEM ATITUDE
# MTG QUEM NÃO QUER SOU EU
# Mtg Forró e Desmantelo
# Mtg Quero Te Encontrar
# Mó Fita
# MTG PASSA PASSA PRA EU SARRAR
# Eu So Comi Ela uma Vez

# %%
"""4. **Artistic Flair**:
   - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
   - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`"""

playlist_tracks = sp.playlist_tracks('37i9dQZF1DWTkIwO2HDifB', limit=10)

track_artist_dict = {}

for item in playlist_tracks['items']:
    track_name = item['track']['name']
    artists = [artist['name'] for artist in item['track']['artists']]
    track_artist_dict[track_name] = artists

print("Track and Artist(s) Dictionary:")
for track, artists in track_artist_dict.items():
    print(f"{track}: {artists}")
# Out:
# Track and Artist(s) Dictionary:
# É Que Eu Te Sarrei: ['DJ THG', 'Mc Arizinho', 'Tavin']
# THE BOX MEDLEY FUNK 2: ['THE BOX', 'Mc Brinquedo', 'MC Cebezinho', 'MC Tuto', 'Mc Laranjinha']
# Samba de Malandro: ['MC Paulin da Capital', 'Love Funk', 'Mc Piedro', 'Dj GM', 'DJ WN', 'MC Ryan SP', 'Mc Daniel']
# QUERO VER SE VOCÊ TEM ATITUDE: ['Dj Luan Gomes']
# MTG QUEM NÃO QUER SOU EU: ['DJ TOPO', 'Seu Jorge', 'Mc Leozin', 'MC G15']
# Mtg Forró e Desmantelo: ['dj sv', 'Doug Hits', 'Manim Vaqueiro']
# Mtg Quero Te Encontrar: ['DJ JZ', 'Humberto & Ronaldo', 'Mc Mininin', 'DJ LG PROD', 'Silvanno Salles']
# Mó Fita: ['Dj Victor', 'MC Tuto', 'MC LUUKY', 'Mc Kadu']
# MTG PASSA PASSA PRA EU SARRAR: ['Mc Livinho', 'DJ TOPO']
# Eu So Comi Ela uma Vez: ['Dj VN Maestro', 'MC G DS']
